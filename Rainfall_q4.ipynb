# %%
import numpy as np
from pandas import Series, DataFrame
import pandas as pd

# %%
#Is there any 3 three consecutive years where rainfall deficit is 10 or more. Find out years in each zone.

# %%
#SOUTH
df1=pd.read_csv('south_pen-India_rainfall_act_dep_1901_2016.csv')
year=df1[df1['Departure Percentage: JUN-SEPT']>=10] [['YEAR']]
year
# Out:
#      YEAR
# 2    1903
# 13   1914
# 15   1916
# 16   1917
# 23   1924
# 32   1933
# 37   1938
# 46   1947
# 52   1953
# 55   1956
# 57   1958
# 58   1959
# 60   1961
# 61   1962
# 63   1964
# 74   1975
# 77   1978
# 80   1981
# 82   1983
# 87   1988
# 88   1989
# 90   1991
# 91   1992
# 95   1996
# 97   1998
# 104  2005
# 106  2007
# 109  2010
# 112  2013

# %%
#NORTHEAST
df_ne=pd.read_csv('ne-India_rainfall_act_dep_1901_2016.csv')
ne=df_ne[df_ne['Departure Percentage: JUN-SEPT']>=10] ['YEAR']
ne
# Out:
# 17     1918
# 21     1922
# 52     1953
# 68     1969
# 69     1970
# 70     1971
# 73     1974
# 83     1984
# 86     1987
# 87     1988
# 98     1999
# 106    2007
# Name: YEAR, dtype: int64

# %%
#NORTHWEST
df_nw=pd.read_csv('nw-India_rainfall_act_dep_1901_2016.csv')
nw=df_nw[df_nw['Departure Percentage: JUN-SEPT']>=10] ['YEAR']
nw
# Out:
# 5      1906
# 7      1908
# 8      1909
# 9      1910
# 13     1914
# 15     1916
# 16     1917
# 21     1922
# 23     1924
# 25     1926
# 32     1933
# 35     1936
# 41     1942
# 42     1943
# 47     1948
# 49     1950
# 52     1953
# 54     1955
# 55     1956
# 56     1957
# 57     1958
# 60     1961
# 70     1971
# 72     1973
# 74     1975
# 75     1976
# 76     1977
# 77     1978
# 87     1988
# 89     1990
# 93     1994
# 94     1995
# 95     1996
# 109    2010
# Name: YEAR, dtype: int64

# %%
#Central INDIA
df_c=pd.read_csv('central-India_rainfall_act_dep_1901_2016.csv')
ce=df_c[df_c['Departure Percentage: JUN-SEPT']>=10] ['YEAR']
ce
# Out:
# 13     1914
# 16     1917
# 18     1919
# 25     1926
# 32     1933
# 33     1934
# 41     1942
# 43     1944
# 44     1945
# 45     1946
# 54     1955
# 55     1956
# 57     1958
# 58     1959
# 60     1961
# 69     1970
# 72     1973
# 74     1975
# 82     1983
# 87     1988
# 93     1994
# 104    2005
# 105    2006
# 112    2013
# Name: YEAR, dtype: int64

# %%
#Which sub-division is the wettest from June to August in the year 2010.

# %%
df_1=pd.read_excel('METEOROLOGICAL_SUB_DIVISION_WISE_ANNUAL_RAINFALL.xls')
df1
# Out:
#      YEAR  Actual Rainfall: JUN  Actual Rainfall: JUL  Actual Rainfall: AUG  \
# 0    1901                 155.8                 191.5                 138.4
# 1    1902                 118.9                 214.4                 159.7
# 2    1903                 141.0                 300.2                 206.2
# 3    1904                 191.9                 191.4                  89.5
# 4    1905                 153.5                 120.6                 187.6
# ..    ...                   ...                   ...                   ...
# 111  2012                 113.0                 178.7                 207.3
# 112  2013                 206.1                 274.6                 164.9
# 113  2014                 100.1                 199.4                 229.1
# 114  2015                 187.6                 110.2                 146.2
# 115  2016                 199.1                 193.3                 108.7
#
#      Actual Rainfall: SEPT  Departure Percentage: JUN  \
# ...

# %%
df=pd.read_excel('MONTHLY_ACTUAL_RAINFALL_FROM_2009_TO_2011.XLS')
df
# Out:
#                              Sub-division   January 2009 (in millimetre)  \
# 0             Andaman and Nicobar Islands                           15.2
# 1                        Arunachal Pradesh                          26.8
# 2                      Assam and Meghalaya                           3.9
# 3   Nagaland,Manipur, Mizoram, and Tripura                           0.1
# 4      Sub-Himalayan,West Bengal & Sikkim                            1.7
# 5                     Gangetic West Bengal                           2.4
# 6                                   Orissa                           0.0
# 7                            Bihar Plateau                           9.2
# 8                             Bihar Plains                           1.5
# 9                       Uttar Pradesh East                           0.1
# 10                     Uttar Pradesh West                            3.3
# 11                            Uttaranchal                            3.5
# ...
