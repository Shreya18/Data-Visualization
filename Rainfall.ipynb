# %%
import numpy as np
from pandas import Series, DataFrame
import pandas as pd

# %%
#SOUTH REGION
df1=pd.read_csv('south_pen-India_rainfall_act_dep_1901_2016.csv')
df1
# Out:
#      YEAR  Actual Rainfall: JUN  Actual Rainfall: JUL  Actual Rainfall: AUG  \
# 0    1901                 155.8                 191.5                 138.4
# 1    1902                 118.9                 214.4                 159.7
# 2    1903                 141.0                 300.2                 206.2
# 3    1904                 191.9                 191.4                  89.5
# 4    1905                 153.5                 120.6                 187.6
# ..    ...                   ...                   ...                   ...
# 111  2012                 113.0                 178.7                 207.3
# 112  2013                 206.1                 274.6                 164.9
# 113  2014                 100.1                 199.4                 229.1
# 114  2015                 187.6                 110.2                 146.2
# 115  2016                 199.1                 193.3                 108.7
#
#      Actual Rainfall: SEPT  Departure Percentage: JUN  \
# ...

# %%
#Which year has more rain in June in the southern region?
df1[df1['Actual Rainfall: JUN']==df1['Actual Rainfall: JUN'].max()][['YEAR','Actual Rainfall: JUN']]
# Out:
#     YEAR  Actual Rainfall: JUN
# 90  1991                 278.0

# %%
#Find the top 5 dry years in south, north-east, north-west and central India.

# %%
#south
south=df1.sort_values('Departure Percentage: JUN-SEPT',ascending=True)[['Departure Percentage: JUN-SEPT','YEAR']].head(5)
south
# Out:
#      Departure Percentage: JUN-SEPT  YEAR
# 17                            -38.7  1918
# 101                           -32.5  2002
# 51                            -28.5  1952
# 4                             -20.3  1905
# 71                            -19.6  1972

# %%
#North EAST
df_ne=pd.read_csv('ne-India_rainfall_act_dep_1901_2016.csv')
ne=df_ne.sort_values('Departure Percentage: JUN-SEPT',ascending=True)[['Departure Percentage: JUN-SEPT','YEAR']].head(5)
ne
# Out:
#      Departure Percentage: JUN-SEPT  YEAR
# 112                           -27.3  2013
# 108                           -24.1  2009
# 104                           -23.5  2005
# 91                            -22.3  1992
# 71                            -18.7  1972

# %%
#North_WEST
df_nw=pd.read_csv('nw-India_rainfall_act_dep_1901_2016.csv')
nw=df_nw.sort_values('Departure Percentage: JUN-SEPT',ascending=True)[['Departure Percentage: JUN-SEPT','YEAR']].head(5)
nw
# Out:
#      Departure Percentage: JUN-SEPT  YEAR
# 17                            -46.9  1918
# 86                            -43.9  1987
# 78                            -41.7  1979
# 108                           -35.5  2009
# 64                            -35.4  1965

# %%
#Central INDIA
df_c=pd.read_csv('central-India_rainfall_act_dep_1901_2016.csv')
ce=df_c.sort_values('Departure Percentage: JUN-SEPT',ascending=True)[['Departure Percentage: JUN-SEPT','YEAR']].head(5)
ce
# Out:
#     Departure Percentage: JUN-SEPT  YEAR
# 17                           -31.1  1918
# 86                           -29.4  1987
# 73                           -28.0  1974
# 71                           -24.5  1972
# 19                           -23.2  1920

# %%
#Write a method which takes inputs – region and Month and return the year during which max rain occurred. (region: south, north-east, north-west and central India (this goes as file name), month: June, July, August and September).\
